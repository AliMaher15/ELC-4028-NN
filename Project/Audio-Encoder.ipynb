# %% [markdown]
# # 1. Import Libraries and Set Directory

# %% [markdown]
# Import Libraries

# %%
is_drive = 1

# %%
if is_drive==1 :
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# directory management
import os
from glob import glob
# regular imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# audio analysis
import librosa 
import librosa.display
import IPython.display as ipd
# imports for colors and plots
from itertools import cycle
sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])
# imports for NN
import tensorflow as tf
from tensorflow import keras
import time
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # 2. Draw Graphs of 1 File

# %% [markdown]
# a function that returns audio in numeric representation

# %% [markdown]
# Read all audio files and sort

# %%
if is_drive==1 :
  train_audio_dir = glob('/content/drive/MyDrive/audio-dataset/Train/*.wav')
else :
  train_audio_dir = glob('../Project/audio-dataset/Train/*.wav')

# %%
# Play audio file
ipd.Audio(train_audio_dir[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# check values and sample rate
y, sr = librosa.load(train_audio_dir[0])
print(f'Amplitude: {y[:10]}')
print(f'shape Amplitude: {y.shape}')
print(f'Sample Rate: {sr}')
# Out:
# Amplitude: [-2.3941860e-05 -3.6772194e-06 -1.7246375e-05 -2.2935763e-05
#  -5.5890227e-06 -1.8038183e-05 -2.2291082e-05 -4.2616621e-06
#  -1.9593919e-05 -2.4858355e-05]
# shape Amplitude: (17640,)
# Sample Rate: 22050

# %%
pd.Series(y).plot(figsize=(8, 4),
                  lw=1,
                  title='Raw Audio Example',
                 color=color_pal[0])
plt.show()

# %% [markdown]
# ## Spectogram

# %%
# Short Time Fourier Transform
D = librosa.stft(y)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
S_db.shape
# Out:
# (1025, 35)

# %%
# Plot the transformed audio data
fig, ax = plt.subplots(figsize=(8,4))
img = librosa.display.specshow(S_db,
                              x_axis='time',
                              y_axis='log',
                              ax=ax)
ax.set_title('Spectogram Example', fontsize=20)
fig.colorbar(img, ax=ax, format=f'%0.2f')
plt.show()

# %% [markdown]
# ## Mel Spectogram

# %%
S = librosa.feature.melspectrogram(y=y,
                                   sr=sr,
                                   n_mels=128,)
S_db_mel = librosa.amplitude_to_db(S, ref=np.max)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
# Plot the mel spectogram
img = librosa.display.specshow(S_db_mel,
                              x_axis='time',
                              y_axis='log',
                              ax=ax)
ax.set_title('Mel Spectogram Example', fontsize=20)
fig.colorbar(img, ax=ax, format=f'%0.2f')
plt.show()

# %% [markdown]
# # 3. Load Spectograms

# %%
# Spectogram Path
if is_drive==1 :   
    TRAIN_DIR = "/content/drive/MyDrive/spectogram-dataset/Train/"
    TEST_DIR = "/content/drive/MyDrive/spectogram-dataset/Test/"
else :
    TRAIN_DIR = "../Project/spectogram-dataset/Train/"
    TEST_DIR = "../Project/spectogram-dataset/Test/"

# %%
def load_fsdd(train_spectrograms_path,test_spectrograms_path):
    x_train = []
    for root, _, file_names in os.walk(train_spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames)
            x_train.append(spectrogram)
    x_train = np.array(x_train)        # -> (n_samples, n_bins, n_frames)
    x_train = x_train[..., np.newaxis] # -> (1200, 256, 22, 1)

    x_test  = []
    for root, _, file_names in os.walk(test_spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames)
            x_test.append(spectrogram)
    x_test = np.array(x_test)        # -> (n_samples, n_bins, n_frames)
    x_test = x_test[..., np.newaxis] # -> (300, 256, 22, 1)

    return x_train,x_test

# %%
x_train, x_test = load_fsdd(TRAIN_DIR, TEST_DIR)

# %% [markdown]
# # 4. AutoEncoder

# %%
from keras import layers

# %%
BATCH_SIZE = 22
EPOCHS = 25
# flatten the dataset
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test  = x_test .reshape((len(x_test ), np.prod(x_test .shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (1200, 5632)
# (300, 5632)

# %%
# the size of compression dimension
encoding_dim = 256 # compression of factor 22 (5632/256), assuming the input is 5632
#input image
input_img = keras.Input(shape=(5632,))
#encoded representation of the input
encoded = layers.Dense(encoding_dim,activation='relu')(input_img)
# lossy reconstruction
decoded = layers.Dense(5632, activation="sigmoid")(encoded)

autoencoder = keras.Model(inputs=input_img, outputs=decoded)

autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5632)]            0
#
#  dense (Dense)               (None, 2816)              15862528
#
#  dense_1 (Dense)             (None, 5632)              15865344
#
# =================================================================
# Total params: 31,727,872
# Trainable params: 31,727,872
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder = keras.Model(inputs=input_img, outputs=encoded)

# %%
encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(inputs=encoded_input, outputs=decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
tic=time.time()
hist = autoencoder.fit( x_train,x_train,
                        epochs=EPOCHS,
                        batch_size=BATCH_SIZE,
                        shuffle=True,
                        #callbacks=[early_stopping],
                        validation_data=(x_test,x_test))
toc=time.time()
training_time=toc-tic
# Out:
# Epoch 1/25
# 55/55 [==============================] - 4s 16ms/step - loss: 0.4169 - val_loss: 0.3951
# Epoch 2/25
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3835 - val_loss: 0.3886
# Epoch 3/25
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3782 - val_loss: 0.3840
# Epoch 4/25
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3754 - val_loss: 0.3823
# Epoch 5/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3738 - val_loss: 0.3808
# Epoch 6/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3724 - val_loss: 0.3798
# Epoch 7/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3715 - val_loss: 0.3794
# Epoch 8/25
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3704 - val_loss: 0.3787
# Epoch 9/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3696 - val_loss: 0.3783
# Epoch 10/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3690 - val_loss: 0.3778
# Epoch 11/25
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3684 - val_loss: 0.3777
# Epoch 12/25
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3681 - val_loss: 0.3773
# Epoch 13/25
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3678 - val_loss: 0.3779
# Epoch 14/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3672 - val_loss: 0.3772
# Epoch 15/25
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3666 - val_loss: 0.3767
# Epoch 16/25
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3662 - val_loss: 0.3770
# Epoch 17/25
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3661 - val_loss: 0.3765
# Epoch 18/25
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3656 - val_loss: 0.3765
# Epoch 19/25
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3651 - val_loss: 0.3763
# Epoch 20/25
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3650 - val_loss: 0.3767
# Epoch 21/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3647 - val_loss: 0.3763
# Epoch 22/25
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3643 - val_loss: 0.3761
# Epoch 23/25
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3640 - val_loss: 0.3760
# Epoch 24/25
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3638 - val_loss: 0.3760
# Epoch 25/25
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3635 - val_loss: 0.3762

# %%
plt.title('Loss')
plt.plot(hist.history['loss'], 'r')
plt.plot(hist.history['val_loss'], 'b')
plt.legend(["Train", "Test"], loc=0, frameon=True)
plt.show()

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step

# %%
#n = 10
#plt.figure(figsize=(20,4))
#for i in range(n):
     # Display Original
#    ax = plt.subplot(2,n,i+1)
#    plt.imshow(x_test[i].reshape(256, 22))
#    ax.get_xaxis().set_visible(False)
#    ax.get_yaxis().set_visible(False)

    # Display Reconstruction
#    ax = plt.subplot(2,n,i+1+n)
#    plt.imshow(decoded_imgs[i].reshape(256, 22))
#    ax.get_xaxis().set_visible(False)
#    ax.get_yaxis().set_visible(False)
#plt.show()

# %%
#autoencoder.save("autoencoder.h5")
#print("saved")
